# %%
import pandas as pd
import matplotlib.pyplot as plt

ucet = pd.read_csv("ucet.csv", names=["datum", "pohyb"])
ucet.set_index("datum", inplace=True)
# ucet.plot(kind="bar")
ucet.cumsum().plot(grid=True, color="red")
# Out:
# <AxesSubplot:xlabel='datum'>
